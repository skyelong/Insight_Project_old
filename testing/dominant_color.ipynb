# %%
import cv2
import numpy as np
import skimage as sk
from skimage import io, transform


img_100 = io.imread('ultramarine_100.jpg')

# %%
img_100.shape
# Out:
# (38, 155, 3)

# %%
img_100
# Out:
# array([[[ 86,  89, 144],
#         [ 95,  97, 172],
#         [ 91,  93, 168],
#         ...,
#         [100, 100, 160],
#         [128, 127, 185],
#         [134, 128, 188]],
#
#        [[ 87,  90, 145],
#         [ 92,  94, 169],
#         [ 95,  97, 172],
#         ...,
#         [101, 101, 161],
#         [106, 105, 163],
#         [120, 114, 174]],
#
#        [[ 84,  87, 142],
#         [104, 106, 183],
#         [ 99, 101, 176],
#         ...,
#         [107, 107, 167],
#         [ 94,  93, 151],
#         [112, 106, 166]],
#
#        ...,
#
#        [[112, 109, 156],
#         [117, 110, 178],
#         [124, 117, 184],
#         ...,
#         [106, 118, 178],
#         [ 98, 108, 179],
#         [ 90,  97, 169]],
#
#        [[123, 120, 167],
#         [116, 109, 177],
#         [110, 103, 171],
#         ...,
#         [ 96, 108, 168],
#         [ 92, 102, 173],
#         [ 83,  90, 162]],
#
#        [[122, 119, 166],
#         [115, 108, 176],
#         [116, 109, 177],
# ...

# %%
img_con_100 = sk.color.convert_colorspace(img_100, 'RGB', 'HSV')

# %%
img_con_100
# Out:
# array([[[0.65804598, 0.40277778, 0.56470588],
#         [0.66233766, 0.44767442, 0.6745098 ],
#         [0.66233766, 0.45833333, 0.65882353],
#         ...,
#         [0.66666667, 0.375     , 0.62745098],
#         [0.66954023, 0.31351351, 0.7254902 ],
#         [0.68333333, 0.31914894, 0.7372549 ]],
#
#        [[0.65804598, 0.4       , 0.56862745],
#         [0.66233766, 0.4556213 , 0.6627451 ],
#         [0.66233766, 0.44767442, 0.6745098 ],
#         ...,
#         [0.66666667, 0.37267081, 0.63137255],
#         [0.66954023, 0.35582822, 0.63921569],
#         [0.68333333, 0.34482759, 0.68235294]],
#
#        [[0.65804598, 0.4084507 , 0.55686275],
#         [0.66244726, 0.43169399, 0.71764706],
#         [0.66233766, 0.4375    , 0.69019608],
#         ...,
#         [0.66666667, 0.35928144, 0.65490196],
#         [0.66954023, 0.38410596, 0.59215686],
#         [0.68333333, 0.36144578, 0.65098039]],
#
#        ...,
#
#        [[0.67730496, 0.30128205, 0.61176471],
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib

# %%
plt.hist(img_con_100[:,:,2])
# Out:
# ([array([ 5.,  5., 10.,  6.,  9.,  3.,  0.,  0.,  0.,  0.]),
#   array([ 0.,  1.,  4.,  6.,  1., 15.,  5.,  5.,  1.,  0.]),
#   array([ 0.,  0.,  1.,  6.,  2., 13.,  7.,  3.,  4.,  2.]),
#   array([ 0.,  0.,  3.,  9., 11.,  9.,  2.,  3.,  1.,  0.]),
#   array([ 0.,  0.,  4.,  6.,  5., 10.,  7.,  6.,  0.,  0.]),
#   array([ 0.,  0.,  1.,  3.,  9.,  8., 11.,  3.,  3.,  0.]),
#   array([0., 1., 3., 3., 9., 8., 8., 5., 0., 1.]),
#   array([0., 1., 2., 7., 6., 7., 3., 8., 3., 1.]),
#   array([0., 2., 0., 7., 5., 6., 8., 7., 3., 0.]),
#   array([ 1.,  1.,  4.,  4., 10.,  6.,  6.,  6.,  0.,  0.]),
#   array([ 0.,  3.,  2.,  6.,  7.,  8., 11.,  1.,  0.,  0.]),
#   array([ 0.,  0.,  2.,  4.,  6., 12., 10.,  3.,  1.,  0.]),
#   array([ 0.,  0.,  0.,  6.,  7., 10.,  8.,  3.,  3.,  1.]),
#   array([ 0.,  0.,  1.,  6., 11.,  9.,  6.,  4.,  1.,  0.]),
#   array([ 0.,  2.,  2.,  6.,  8., 16.,  2.,  2.,  0.,  0.]),
#   array([ 0.,  0.,  3.,  2.,  8.,  9., 13.,  3.,  0.,  0.]),
# ...

# %%
plt.hist(img_con_100[:,:,0]);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-02973a7b6bb9> in <module>
# ----> 1 plt.hist(img_con_100[:,:,0]);
#
# NameError: name 'plt' is not defined

# %%
plt.hist(img_con_100[:,:,1])
# Out:
# ([array([ 3., 16.,  5.,  5.,  7.,  2.,  0.,  0.,  0.,  0.]),
#   array([ 0.,  0.,  3.,  9., 10.,  5.,  7.,  4.,  0.,  0.]),
#   array([ 0.,  0.,  5.,  9., 13.,  3.,  4.,  3.,  1.,  0.]),
#   array([ 0.,  2., 14.,  9.,  7.,  3.,  3.,  0.,  0.,  0.]),
#   array([ 0.,  6., 15.,  6.,  8.,  1.,  2.,  0.,  0.,  0.]),
#   array([ 1.,  2., 20.,  5., 10.,  0.,  0.,  0.,  0.,  0.]),
#   array([ 2.,  5.,  9., 12.,  7.,  2.,  1.,  0.,  0.,  0.]),
#   array([ 2.,  9.,  9., 11.,  3.,  4.,  0.,  0.,  0.,  0.]),
#   array([ 2.,  7., 11.,  7.,  7.,  4.,  0.,  0.,  0.,  0.]),
#   array([ 2.,  6.,  8.,  8., 10.,  1.,  3.,  0.,  0.,  0.]),
#   array([ 0.,  4., 15.,  9.,  4.,  2.,  1.,  3.,  0.,  0.]),
#   array([ 0.,  9., 14.,  6.,  4.,  3.,  1.,  1.,  0.,  0.]),
#   array([ 2.,  7., 10., 10.,  4.,  4.,  0.,  1.,  0.,  0.]),
#   array([ 0.,  9., 10.,  6.,  8.,  3.,  1.,  1.,  0.,  0.]),
#   array([ 0.,  7., 11.,  7.,  6.,  5.,  2.,  0.,  0.,  0.]),
# ...

# %%
average = img_con_100.mean(axis=0).mean(axis=0)

# %%
average = img_con_100.mean(axis=0)

# %%
average.shape
# Out:
# (155, 3)

# %%
img_75 = io.imread('ultramarine_75.jpg')

# %%
img_con_75 = sk.color.convert_colorspace(img_75, 'RGB', 'HSV')

# %%
average_75 = img_con_75.mean(axis=0)
average_75
# Out:
# array([[0.65727637, 0.47373685, 0.55647059],
#        [0.65241154, 0.52338331, 0.63607843],
#        [0.65337366, 0.51262165, 0.64784314],
#        [0.6624149 , 0.45450274, 0.62980392],
#        [0.66101979, 0.41970064, 0.63529412],
#        [0.66271867, 0.38132675, 0.63862745],
#        [0.66474754, 0.35051582, 0.68745098],
#        [0.66980547, 0.34339786, 0.68568627],
#        [0.67965034, 0.33730362, 0.70764706],
#        [0.68266977, 0.33914066, 0.69254902],
#        [0.68353782, 0.33104997, 0.69784314],
#        [0.68800493, 0.32278425, 0.69627451],
#        [0.6861689 , 0.31505852, 0.71254902],
#        [0.67974973, 0.31071362, 0.69235294],
#        [0.67958274, 0.30273162, 0.70196078],
#        [0.67826001, 0.28692802, 0.71509804],
#        [0.67742986, 0.28115165, 0.72156863],
#        [0.6804134 , 0.29260801, 0.69490196],
#        [0.68990843, 0.29355917, 0.68745098],
#        [0.69044834, 0.28207377, 0.71137255],
#        [0.69024118, 0.28680173, 0.69431373],
# ...

# %%
img_50 = io.imread('ultramarine_50.jpg')
img_con_50 = sk.color.convert_colorspace(img_50, 'RGB', 'hsv')
average_50 = img_con_50.mean(axis=0)
average_50
# Out:
# array([[0.69362748, 0.26615529, 0.74411765],
#        [0.69439681, 0.2388735 , 0.75431373],
#        [0.69497128, 0.23763085, 0.76235294],
#        [0.70110506, 0.25172494, 0.7545098 ],
#        [0.70351796, 0.24736263, 0.74941176],
#        [0.70239161, 0.24347614, 0.76019608],
#        [0.70213662, 0.23861936, 0.77705882],
#        [0.7031827 , 0.237427  , 0.76078431],
#        [0.70215201, 0.23999949, 0.75627451],
#        [0.70304168, 0.23659849, 0.74882353],
#        [0.70304168, 0.23358554, 0.75862745],
#        [0.70362118, 0.22845235, 0.75823529],
#        [0.70394076, 0.23056619, 0.75      ],
#        [0.70300805, 0.22800165, 0.75019608],
#        [0.70320222, 0.22431786, 0.75647059],
#        [0.70357877, 0.21503453, 0.77529412],
#        [0.70369656, 0.22074924, 0.76058824],
#        [0.70345439, 0.21483408, 0.77117647],
#        [0.70177779, 0.21217968, 0.78294118],
#        [0.7007012 , 0.22395747, 0.76039216],
#        [0.70056231, 0.22735826, 0.75117647],
# ...
