# %%
import pandas as pd
from sqlalchemy import create_engine
from sqlalchemy_utils import database_exists, create_database
import psycopg2
import pandas as pd
import sys
sys.path.append('/Users/macbook/Box/git_hub/Insight_Project_clean/scripts/')
#import scripts.sql_con as sql

# %%
colors_df = pd.read_csv("/Users/macbook/Box/git_hub/flask3/data/colors_data2.csv")

# %%
colors_df
# Out:
#                        name  \
# 0           Imperial Purple
# 1           Aussie Red Gold
# 2             Buff Titanium
# 3   Bismuth Vanadate Yellow
# 4        Hansa Yellow Light
# ..                      ...
# 74             Neutral Tint
# 75             Payne’s Gray
# 76              Lunar Black
# 77            Chinese White
# 78           Titanium White
#
#                                                   url  \
# 0   http://danielsmith.com/imperial-purple-5ml-tub...
# 1   http://danielsmith.com/aussie-red-gold-5ml-tub...
# 2   http://danielsmith.com/buff-titanium-5ml-tube-...
# 3   http://danielsmith.com/bismuth-vanadate-yellow...
# 4   http://danielsmith.com/hansa-yellow-light-5ml-...
# ..                                                ...
# 74  http://danielsmith.com/neutral-tint-5ml-tube-d...
# 75  http://danielsmith.com/paynes-gray-5ml-tube-da...
# 76  http://danielsmith.com/lunar-black-5ml-tube-da...
# 77  http://danielsmith.com/chinese-white-5ml-tube-...
# ...

# %%
import sql_con
from sql_con import df_from_query
# Out:
# postgresql://macbook:DarwinRulez!1@localhost/colors

# %%
sql_query = """SELECT * FROM ds_data"""
df = df_from_query(sql_query)

df
# Out:
# postgresql://macbook:DarwinRulez!1@localhost/colors
#     index                     name  \
# 0       0          Imperial Purple
# 1       1          Aussie Red Gold
# 2       2            Buff Titanium
# 3       3  Bismuth Vanadate Yellow
# 4       4       Hansa Yellow Light
# ..    ...                      ...
# 74     74             Neutral Tint
# 75     75             Payne’s Gray
# 76     76              Lunar Black
# 77     77            Chinese White
# 78     78           Titanium White
#
#                                             file_path  \
# 0   /Users/macbook/Box/insight_project_data/swatch...
# 1   /Users/macbook/Box/insight_project_data/swatch...
# 2   /Users/macbook/Box/insight_project_data/swatch...
# 3   /Users/macbook/Box/insight_project_data/swatch...
# 4   /Users/macbook/Box/insight_project_data/swatch...
# ..                                                ...
# 74  /Users/macbook/Box/insight_project_data/swatch...
# ...

# %%
file_name = df['crop_path'][1].split("/")[-1]

# %%
file_name
# Out:
# 'aussie_red_gold_crop.jpg'

# %%
colors_df["image_name"] = df['crop_path'][].split("/")[-1]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-9c57b80ab42b> in <module>
# ----> 1 colors_df["image_name"] = df['crop_path'].split("/")[-1]
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'split'

# %%
names = []

# %%
for i in range(0,len(df)):
    file_name = df['crop_path'][i].split("/")[-1]
    names.append(file_name)

# %%
names
# Out:
# ['imperial_purple_crop.jpg',
#  'aussie_red_gold_crop.jpg',
#  'buff_titanium_crop.jpg',
#  'bismuth_vanadate_yellow_crop.jpg',
#  'hansa_yellow_light_crop.jpg',
#  'cadmium_yellow_light_hue_crop.jpg',
#  'cadmium_yellow_medium_hue_crop.jpg',
#  'aureolin__cobalt_yellow_crop.jpg',
#  'hansa_yellow_medium_crop.jpg',
#  'lemon_yellow_crop.jpg',
#  'indian_yellow_crop.jpg',
#  'naples_yellow_crop.jpg',
#  'new_gamboge_crop.jpg',
#  'pyrrol_orange_crop.jpg',
#  'perinone_orange_crop.jpg',
#  'transparent_pyrrol_orange_crop.jpg',
#  'organic_vermilion_crop.jpg',
#  'quinacridone_coral_crop.jpg',
#  'pyrrol_scarlet_crop.jpg',
#  'cadmium_red_medium_hue_crop.jpg',
#  'pyrrol_red_crop.jpg',
#  'quinacridone_red_crop.jpg',
#  'alizarin_crimson_crop.jpg',
#  'permanent_alizarin_crimson_crop.jpg',
#  'opera_pink_crop.jpg',
#  'quinacridone_pink_crop.jpg',
#  'quinacridone_rose_crop.jpg',
#  'quinacridone_magenta_crop.jpg',
#  'quinacridone_violet_crop.jpg',
#  'cobalt_violet_crop.jpg',
# ...

# %%
colors_df["image_names"] = names

# %%
colors_df
# Out:
#                        name  \
# 0           Imperial Purple
# 1           Aussie Red Gold
# 2             Buff Titanium
# 3   Bismuth Vanadate Yellow
# 4        Hansa Yellow Light
# ..                      ...
# 74             Neutral Tint
# 75             Payne’s Gray
# 76              Lunar Black
# 77            Chinese White
# 78           Titanium White
#
#                                                   url  \
# 0   http://danielsmith.com/imperial-purple-5ml-tub...
# 1   http://danielsmith.com/aussie-red-gold-5ml-tub...
# 2   http://danielsmith.com/buff-titanium-5ml-tube-...
# 3   http://danielsmith.com/bismuth-vanadate-yellow...
# 4   http://danielsmith.com/hansa-yellow-light-5ml-...
# ..                                                ...
# 74  http://danielsmith.com/neutral-tint-5ml-tube-d...
# 75  http://danielsmith.com/paynes-gray-5ml-tube-da...
# 76  http://danielsmith.com/lunar-black-5ml-tube-da...
# 77  http://danielsmith.com/chinese-white-5ml-tube-...
# ...

# %%
dbname = 'colors'
username = 'macbook'
pswd = 'DarwinRulez!1'
engine = create_engine('postgresql://%s:%s@localhost/%s'%(username,pswd,dbname))
print('postgresql://%s:%s@localhost/%s'%(username,pswd,dbname))
print(engine.url)
colors_df.to_sql('web_data', engine, if_exists='replace')
# Out:
# postgresql://macbook:DarwinRulez!1@localhost/colors
# postgresql://macbook:DarwinRulez!1@localhost/colors

# %%
sql_query = """SELECT * FROM web_data"""
df2 = df_from_query(sql_query)

df2
# Out:
# postgresql://macbook:DarwinRulez!1@localhost/colors
#     index                     name  \
# 0       0          Imperial Purple
# 1       1          Aussie Red Gold
# 2       2            Buff Titanium
# 3       3  Bismuth Vanadate Yellow
# 4       4       Hansa Yellow Light
# ..    ...                      ...
# 74     74             Neutral Tint
# 75     75             Payne’s Gray
# 76     76              Lunar Black
# 77     77            Chinese White
# 78     78           Titanium White
#
#                                                   url  \
# 0   http://danielsmith.com/imperial-purple-5ml-tub...
# 1   http://danielsmith.com/aussie-red-gold-5ml-tub...
# 2   http://danielsmith.com/buff-titanium-5ml-tube-...
# 3   http://danielsmith.com/bismuth-vanadate-yellow...
# 4   http://danielsmith.com/hansa-yellow-light-5ml-...
# ..                                                ...
# 74  http://danielsmith.com/neutral-tint-5ml-tube-d...
# ...
