# %% [markdown]
# # Test scripts for the watercolorist app
#
# To Do:
# 1. Collect pigment information from websites and merge into single database
#     a. Data base must have the pigment#, color name, manufacturer (limit to 3 major manufacturers(Daniel Smith, M  Graham & Windsor Newton)
#     b. Generate HSV or RGB profiles for swatches of pure pigments and merge to pigment database
#     c. Generate HSV or RGB profiles for common color mixes from web images for
#         1. neutrals
#         2. greens
#         3. skintones
# 2. Segment image into color zones using K-means clustering
#     a. Generate HSV or RGB profiles for color zones
#         1. Must ignore white
#     b. Use K-Means clustering on each segment to match to colors in database
#         1. Return the "convience color" and "mixed color match"
#             a. return should have image of closest matches from all three manufacturers starting with the closest for both the mix and the convience color
#             b. return price information
#             c. return toxicity, color-fastness, pigment number
#
# 3. Possibly allow the user to prioritize one of the features?
# 4. Maybe link to videos or images of tutorial on painting the topic of what they are painting? Flowers, birds, portaits?
# 5. Maybe link to swatching videos or reviews of pigments?
#
#
# Feedback - Need to focus on one thing, scope.
# limit to one manufacturer at first
# skip the tensorflow
# find different segmentation method then k-means
#
#
# My thoughts
# I need to deal with saturation, can this be simulated?
#
#
# Test with one pure and one mixed pigments at different value scales.
#
# ##inital steps
# Color clusering -
# 1. scrape the 88 5ml colors from the daniel smith website
# 2. get hsv or rgb colors for swatch
# 3. label with general colors for primary and secondary colors. hot encoding
# 4. can I just use a linear model??? find the point closest to it based on the hsv or rgb values???? return value with the smallest distance? Sounds like a cross-validate!
# 4. Test/train to to see which classifier can group colors with highest accuracy
# 5. Test with new set of swatches from the internet
#
# Color identification
# 1. find best way to identify colors meaningfully, how many segments??? Which model
# 2. Test initially on color wheel using known pigments
# 3. Try to match labeled segmented regions of known pigments to the color model
# 4.

# %% [markdown]
# ## 1. Web scraping information from manufacturers websites
# Daniel Smith 150 primary colors - ignore perlecent colors
#
# Using Chrome the webpages are organized as:
# danielsmith.com/color-name-5ml-tube-daniel-smith-extra-fine-watercolor/
# The color names are the only things that change - get list and generate for loop to create automated downloads
#
# Tag for the image is:
# <meta property="og:image" content="http://danielsmith.com/wp-content/uploads/284610009_112817.jpg" />
#
# Tag for the information is:
# <div id="post-2100" class="section section-post-content post-2100 post type-post status-publish format-standard has-post-thumbnail hentry category-product category-wc5ml lightfastness-all lightfastness-lightfastness-i-excellent granulation-all granulation-granulation-granulating staining-all staining-staining-1-non-staining transparency-all transparency-transparency-semi-opaque colorfamily-all colorfamily-white colorfamily-yellow type-all">
# 	<div class="section the_content"><div class="section_wrapper"><div class="the_content_wrapper"><p>Spatter or drop a brushload of Buff Titanium into a moist wash and enjoy the pigment displacement, it is especially effective used that way to make clouds in the sky. Unique to DANIEL SMITH, Buff Titanium resembles the ecru shades of sand and antique lace and simulates the porous texture of an eggshell. It is a most welcome neutral, with its&#8217; semi-transparent to opaque, non-staining properties. Pre-mix Buff Titanium with Quinacridone Rose or Perinone Orange for subtle hues and matte surfaces ideal for the velvety petals of your favorite flowers. Mix with Indigo or Van Dyke Brown to create slate-colored shadows and soft feathers. Glaze a dried landscape with a misty, atmospheric mood.</p>
# <p>SKU: 284610009<br />
# Pigment: PW 6:1 | Series: 1<br />
# Lightfastness: I &#8211; Excellent<br />
# Transparency: Semi-Opaque<br />
# Staining: 1-Non-Staining<br />
# Granulation: Granulating</p>

# %%
import requests
from bs4 import BeautifulSoup

# %%
#url of the watercolor page - this will be turned into a function later
url = "http://danielsmith.com/undersea-green-5ml-tube-daniel-smith-extra-fine-watercolor/"

webpage_response = requests.get(url, "html.parser")
soup = BeautifulSoup(webpage_response.content)
print(soup)
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7 ]><html class="ie ie6" lang="en"> <![endif]--><!--[if IE 7 ]><html class="ie ie7" lang="en"> <![endif]--><!--[if IE 8 ]><html class="ie ie8" lang="en"> <![endif]--><!--[if (gte IE 9)|!(IE)]><!--><html lang="en-US"> <!--<![endif]-->
# <!-- head -->
# <head>
# <!-- meta -->
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="x-ua-compatible"/>
# <meta content="width=device-width, initial-scale=1, maximum-scale=1" name="viewport"/>
# <title>Undersea Green 5ml Tube - DANIEL SMITH Extra Fine Watercolor - DANIEL SMITHDANIEL SMITH</title>
# <link href="http://danielsmith.com/wp-content/uploads/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <!-- wp_head() -->
# <script>
# //<![CDATA[
# window.mfn_slider_vertical	= { autoplay:10000 	};
# window.mfn_slider_portfolio 	= { autoPlay:0 };
# //]]>
# </script>
# <!-- This site is optimized with the Yoast SEO plugin v13.0 - https://yoast.com/wordpress/plugins/seo/ -->
# <meta content="max-snippet:-1, max-image-preview:large, max-video-preview:-1" name="robots"/>
# <link href="http://danielsmith.com/undersea-green-5ml-tube-daniel-smith-extra-fine-watercolor/" rel="canonical"/>
# <meta content="en_US" property="og:locale"/>
# <meta content="article" property="og:type"/>
# <meta content="Undersea Green 5ml Tube - DANIEL SMITH Extra Fine Watercolor - DANIEL SMITH" property="og:title"/>
# <meta content="An artist’s favorite, this exciting medium to high staining green blends French Ultramarine with Quinacridone Gold. The inorganic, sedimentary French Ultramarine settles and granulates while the …" property="og:description"/>
# <meta content="http://danielsmith.com/undersea-green-5ml-tube-daniel-smith-extra-fine-watercolor/" property="og:url"/>
# <meta content="DANIEL SMITH" property="og:site_name"/>
# <meta content="All" property="article:section"/>
# <meta content="2017-12-21T17:22:15+00:00" property="article:published_time"/>
# <meta content="http://danielsmith.com/wp-content/uploads/284610109_112817.jpg" property="og:image"/>
# <meta content="400" property="og:image:width"/>
# <meta content="400" property="og:image:height"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="An artist’s favorite, this exciting medium to high staining green blends French Ultramarine with Quinacridone Gold. The inorganic, sedimentary French Ultramarine settles and granulates while the […]" name="twitter:description"/>
# <meta content="Undersea Green 5ml Tube - DANIEL SMITH Extra Fine Watercolor - DANIEL SMITH" name="twitter:title"/>
# <meta content="http://danielsmith.com/wp-content/uploads/284610109_112817.jpg" name="twitter:image"/>
# <script class="yoast-schema-graph yoast-schema-graph--main" type="application/ld+json">{"@context":"https://schema.org","@graph":[{"@type":"WebSite","@id":"http://danielsmith.com/#website","url":"http://danielsmith.com/","name":"DANIEL SMITH","potentialAction":{"@type":"SearchAction","target":"http://danielsmith.com/?s={search_term_string}","query-input":"required name=search_term_string"}},{"@type":"ImageObject","@id":"http://danielsmith.com/undersea-green-5ml-tube-daniel-smith-extra-fine-watercolor/#primaryimage","url":"http://danielsmith.com/wp-content/uploads/284610109_112817.jpg","width":400,"height":400},{"@type":"WebPage","@id":"http://danielsmith.com/undersea-green-5ml-tube-daniel-smith-extra-fine-watercolor/#webpage","url":"http://danielsmith.com/undersea-green-5ml-tube-daniel-smith-extra-fine-watercolor/","inLanguage":"en-US","name":"Undersea Green 5ml Tube - DANIEL SMITH Extra Fine Watercolor - DANIEL SMITH","isPartOf":{"@id":"http://danielsmith.com/#website"},"primaryImageOfPage":{"@id":"http://danielsmith.com/undersea-green-5ml-tube-daniel-smith-extra-fine-watercolor/#primaryimage"},"datePublished":"2017-12-21T17:22:15+00:00","dateModified":"2017-12-21T17:22:15+00:00","author":{"@id":"http://danielsmith.com/#/schema/person/f4a017403303df72875f90441e72a27b"}},{"@type":["Person"],"@id":"http://danielsmith.com/#/schema/person/f4a017403303df72875f90441e72a27b","name":"Jodi Steele","image":{"@type":"ImageObject","@id":"http://danielsmith.com/#authorlogo","url":"http://0.gravatar.com/avatar/91fc593192cf01a328fff85104de8a1a?s=96&d=mm&r=g","caption":"Jodi Steele"},"sameAs":[]}]}</script>
# <!-- / Yoast SEO plugin. -->
# <link href="//code.jquery.com" rel="dns-prefetch"/>
# <link href="//translate.google.com" rel="dns-prefetch"/>
# <link href="//fonts.googleapis.com" rel="dns-prefetch"/>
# <link href="//s.w.org" rel="dns-prefetch"/>
# <link href="http://danielsmith.com/feed/" rel="alternate" title="DANIEL SMITH » Feed" type="application/rss+xml"/>
# <link href="http://danielsmith.com/comments/feed/" rel="alternate" title="DANIEL SMITH » Comments Feed" type="application/rss+xml"/>
# <script type="text/javascript">
# 			window._wpemojiSettings = {"baseUrl":"https:\/\/s.w.org\/images\/core\/emoji\/12.0.0-1\/72x72\/","ext":".png","svgUrl":"https:\/\/s.w.org\/images\/core\/emoji\/12.0.0-1\/svg\/","svgExt":".svg","source":{"concatemoji":"http:\/\/danielsmith.com\/wp-includes\/js\/wp-emoji-release.min.js?ver=5.4.1"}};
# 			/*! This file is auto-generated */
# 			!function(e,a,t){var r,n,o,i,p=a.createElement("canvas"),s=p.getContext&&p.getContext("2d");function c(e,t){var a=String.fromCharCode;s.clearRect(0,0,p.width,p.height),s.fillText(a.apply(this,e),0,0);var r=p.toDataURL();return s.clearRect(0,0,p.width,p.height),s.fillText(a.apply(this,t),0,0),r===p.toDataURL()}function l(e){if(!s||!s.fillText)return!1;switch(s.textBaseline="top",s.font="600 32px Arial",e){case"flag":return!c([127987,65039,8205,9895,65039],[127987,65039,8203,9895,65039])&&(!c([55356,56826,55356,56819],[55356,56826,8203,55356,56819])&&!c([55356,57332,56128,56423,56128,56418,56128,56421,56128,56430,56128,56423,56128,56447],[55356,57332,8203,56128,56423,8203,56128,56418,8203,56128,56421,8203,56128,56430,8203,56128,56423,8203,56128,56447]));case"emoji":return!c([55357,56424,55356,57342,8205,55358,56605,8205,55357,56424,55356,57340],[55357,56424,55356,57342,8203,55358,56605,8203,55357,56424,55356,57340])}return!1}function d(e){var t=a.createElement("script");t.src=e,t.defer=t.type="text/javascript",a.getElementsByTagName("head")[0].appendChild(t)}for(i=Array("flag","emoji"),t.supports={everything:!0,everythingExceptFlag:!0},o=0;o<i.length;o++)t.supports[i[o]]=l(i[o]),t.supports.everything=t.supports.everything&&t.supports[i[o]],"flag"!==i[o]&&(t.supports.everythingExceptFlag=t.supports.everythingExceptFlag&&t.supports[i[o]]);t.supports.everythingExceptFlag=t.supports.everythingExceptFlag&&!t.supports.flag,t.DOMReady=!1,t.readyCallback=function(){t.DOMReady=!0},t.supports.everything||(n=function(){t.readyCallback()},a.addEventListener?(a.addEventListener("DOMContentLoaded",n,!1),e.addEventListener("load",n,!1)):(e.attachEvent("onload",n),a.attachEvent("onreadystatechange",function(){"complete"===a.readyState&&t.readyCallback()})),(r=t.source||{}).concatemoji?d(r.concatemoji):r.wpemoji&&r.twemoji&&(d(r.twemoji),d(r.wpemoji)))}(window,document,window._wpemojiSettings);
# 		</script>
# <style type="text/css">
# img.wp-smiley,
# img.emoji {
# 	display: inline !important;
# 	border: none !important;
# 	box-shadow: none !important;
# 	height: 1em !important;
# 	width: 1em !important;
# 	margin: 0 .07em !important;
# 	vertical-align: -0.1em !important;
# 	background: none !important;
# 	padding: 0 !important;
# }
# </style>
# <link href="http://danielsmith.com/wp-content/plugins/grid-products/styles.css" id="products-css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="http://danielsmith.com/wp-content/plugins/content-views-query-and-display-post-page/public/assets/css/cv.css?ver=2.3.1" id="pt-cv-public-style-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="http://danielsmith.com/wp-includes/css/dist/block-library/style.min.css?ver=5.4.1" id="wp-block-library-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="http://danielsmith.com/wp-content/plugins/column-shortcodes//assets/css/shortcodes.css?ver=1.0" id="cpsh-shortcodes-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="http://danielsmith.com/wp-content/plugins/contact-form-7/includes/css/styles.css?ver=5.1.6" id="contact-form-7-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="http://danielsmith.com/wp-content/plugins/google-language-translator/css/style.css?ver=6.0.4" id="google-language-translator-css" media="" rel="stylesheet" type="text/css"/>
# <link href="http://danielsmith.com/wp-content/plugins/widget-options/assets/css/widget-options.css" id="widgetopts-styles-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="http://danielsmith.com/wp-content/themes/brandon/style.css?ver=1.9.4" id="style-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="http://danielsmith.com/wp-content/themes/brandon/css/prettyPhoto.css?ver=1.9.4" id="prettyPhoto-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="http://danielsmith.com/wp-content/themes/brandon/js/owl-carousel/owl.carousel.css?ver=1.9.4" id="owl-carousel-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="http://danielsmith.com/wp-content/themes/brandon/js/owl-carousel/owl.theme.css?ver=1.9.4" id="owl-theme-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="http://danielsmith.com/wp-content/themes/brandon/css/ui/jquery.ui.all.css?ver=1.9.4" id="jquery-ui-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="http://danielsmith.com/wp-content/themes/brandon/css/responsive.css?ver=1.9.4" id="responsive-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="http://danielsmith.com/wp-content/themes/brandon/css/skins/red/images.css?ver=1.9.4" id="images-green-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="http://danielsmith.com/wp-content/themes/brandon/style-colors.php?ver=1.9.4" id="style-colors-php-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="http://danielsmith.com/wp-content/themes/brandon/style.php?ver=1.9.4" id="style-php-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="http://danielsmith.com/wp-content/themes/brandon/fonts/raleway.css?ver=1.9.4" id="webfont-raleway-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="http://fonts.googleapis.com/css?family=Exo%3A400&amp;ver=5.4.1" id="Varela-css" media="all" rel="stylesheet" type="text/css"/>
# <link href="http://danielsmith.com/wp-content/themes/brandon/css/woocommerce.css?ver=1.9.4" id="mfn-woo-css" media="all" rel="stylesheet" type="text/css"/>
# <script src="//code.jquery.com/jquery-1.11.3.min.js?ver=1.11.3" type="text/javascript"></script>
# <script type="text/javascript">
# /* <![CDATA[ */
# var wpgmza_google_api_status = {"message":"Enqueued","code":"ENQUEUED"};
# /* ]]> */
# </script>
# <script src="http://danielsmith.com/wp-content/plugins/wp-google-maps/wpgmza_data.js?ver=5.4.1" type="text/javascript"></script>
# <link href="http://danielsmith.com/wp-json/" rel="https://api.w.org/"/>
# <link href="http://danielsmith.com/xmlrpc.php?rsd" rel="EditURI" title="RSD" type="application/rsd+xml"/>
# <link href="http://danielsmith.com/wp-includes/wlwmanifest.xml" rel="wlwmanifest" type="application/wlwmanifest+xml"/>
# <meta content="WordPress 5.4.1" name="generator"/>
# <link href="http://danielsmith.com/?p=2035" rel="shortlink"/>
# <link href="http://danielsmith.com/wp-json/oembed/1.0/embed?url=http%3A%2F%2Fdanielsmith.com%2Fundersea-green-5ml-tube-daniel-smith-extra-fine-watercolor%2F" rel="alternate" type="application/json+oembed"/>
# <link href="http://danielsmith.com/wp-json/oembed/1.0/embed?url=http%3A%2F%2Fdanielsmith.com%2Fundersea-green-5ml-tube-daniel-smith-extra-fine-watercolor%2F&amp;format=xml" rel="alternate" type="text/xml+oembed"/>
# <style type="text/css">#google_language_translator a {display: none !important; }.goog-te-gadget {color:transparent !important;}.goog-te-gadget { font-size:0px !important; }.goog-branding { display:none; }.goog-tooltip {display: none !important;}.goog-tooltip:hover {display: none !important;}.goog-text-highlight {background-color: transparent !important; border: none !important; box-shadow: none !important;}#flags { display:none; }.goog-te-banner-frame{visibility:hidden !important;}body { top:0px !important;}</style><style type="text/css">
# .taxonomy-drilldown-lists p,
# .taxonomy-drilldown-checkboxes p,
# .taxonomy-drilldown-dropdowns p {
# 	margin-top: 1em;
# }
#
# .taxonomy-drilldown-checkboxes li,
# .taxonomy-drilldown-dropdowns li {
# 	list-style: none;
# }
#
# .taxonomy-drilldown-dropdowns select {
# 	display: block;
# }
# </style>
# <link href="http://danielsmith.com/wp-content/themes/brandon/css/custom.css?ver=1.9.4" media="all" rel="stylesheet"/>
# <style>
# body {
# 	font-family: "Roboto","Helvetica Neue",Helvetica,Arial,sans-serif;
# 	font-size: 12px;
# 	line-height: 16px;
# 	color: #333;
# }
#
# .section-post-about .author-box {
# 	margin-top: 20px;
#         display:none;
# }
#
# .archive .post {
# 	width: 20%;
# }
#
# .archive .post p {
# 	display: none;
# }
#
# .archive .post .more {
# 	display: none;
# }
#
# #comments {
# 	padding-top: 30px;
# 	margin-top: 20px;
# 	background: url(../images/divider.png) repeat-x left top;
# display:none;
# }
#
# #Subheader ul.breadcrumbs {
#     float: right;
#     margin: 0 0 15px;
#     overflow: hidden;
#     text-align: right;
#     font-size: 13px;
# /* display:none; */
# }
#
# p {
# 	margin: 0 0 15px 0;
# }
#
# .latest_posts_wrapper .desc .date {
# 	display: none;
# 	margin-bottom: 5px;
# }
#
# #Subheader {
# 	text-align: center;
# 	background-image:
#
# url(../public_html/wp-content/uploads/2x2.jpg);
# 	background-repeat: no-repeat;
# 	background-position: top center;
# 	font-size: x-large;
# }
#
# .single-portfolio .portfolio_meta .portfolio_desc {
# 	width: 47%;
# 	margin-left: 3%;
# 	float: right;
# 	padding-top: 5px;
#         display: none;
# }
#
# .footer_line {
# display:none;
# }
#
# .slider1 {
#   background-image: url(../upload/portfolio_5.jpg);
#   height: 610px;
# }
#
# #mfn-slider .swiper-wrapper {
#   position: relative;
#   height: 610px !important;
# }
#
# #mfn-slider .swiper-container, #mfn-slider .swiper-slide {
#   height: 610px !important;
#   line-height: 600px;
#   width: 100%;
# }
#
# #mfn-slider .swiper-slide .button {
# 	color: #ffffff;
# 	border-color: #fff;
# }
#
# #mfn-slider .swiper-slide .button {
# 	margin-top: 10px;
# 	background-color: #467e9f;
# 	border-width: 0px;
# 	border-style: solid;
# }
#
# a.button, a.tp-button, button, input[type="submit"], input[type="reset"],
#
# input[type="button"] {
# 	display: inline-block;
# 	padding: 15px 50px;
# 	font-size: 14px;
# 	line-height: 14px;
# 	margin-bottom: 15px;
# 	-webkit-border-radius: 6px;
# 	border-radius: 6px;
# 	position: relative;
# 	-webkit-transition: all 0.3s;
# 	-moz-transition: all 0.3s;
# 	transition: all 0.3s;
# 	background: none;
# 	z-index: 1;
# 	cursor: pointer;
# 	text-transform: uppercase;
# 	letter-spacing: 2px;
# 	background-image: none;
# 	border: 0;
# 	margin-right: 7px;
# }
#
# .menu-clean #Header #menu {
# 	background: #467e9f;
#         width:100%;
# }
#
# .section_wrapper, .container {
# 	width: 100%;
# 	margin: 0 auto;
# 	position: relative;
# }
#
# .menu-clean #Header .menu > li > a {
# 	padding: 0 20px;
# 	color: #ffffff;
# }
#
# code, pre {
# 	background: #ffffff;
# 	/* background: -moz-linear-gradient(top, #ffffff 50%, #f2f2f2 50%); */
# 	/* background: -webkit-linear-gradient(top, #ffffff 50%,#f2f2f2 50%);
#
# */
# 	/* background: -o-linear-gradient(top, #ffffff 50%,#f2f2f2 50%); */
# 	/* background: linear-gradient(top, #ffffff 50%,#f2f2f2 50%); */
# 	background-size: 42px 42px;
# 	padding: 21px 15px 20px;
# 	margin: 15px 0;
# 	display: block;
# 	white-space: pre-wrap;
# 	white-space: -moz-pre-wrap;
# 	white-space: -pre-wrap;
# 	white-space: -o-pre-wrap;
# 	line-height: 21px !important;
# 	border-width: 0px;
# 	border-style: solid;
# 	font-family: monospace !important;
# }
#
# .section {
# 	clear: both;
# 	padding: 0px;
# 	margin: 0px;
#         margin-left: 40px;
#         margin-right: 40px;
# }
#
# a.button, a.tp-button, button, input[type="submit"], input[type="reset"],
#
# input[type="button"] {
# 	display: inline-block;
# 	padding: 20px 50px;
# 	font-size: 14px;
# 	line-height: 14px;
# 	margin-bottom: 15px;
# 	-webkit-border-radius: 0px;
#        border-radius: 0px;
# }
#
# .one.column {
# 	width: 100%;
# }
#
# .column, .columns {
# 	float: left;
# 	margin: 0 0% 0px;
# }
#
# body {
# 	font-family: "Roboto","Helvetica Neue",Helvetica,Arial,sans-serif;
# 	font-size: 14px;
# 	line-height: 20px;
# 	color: #333;
# }
#
# #Header .menu > li > a {
# 	display: inline-block;
# 	white-space: nowrap;
# 	padding: 0px 25px;
# 	line-height: 60px;
# 	text-transform: none;
# 	letter-spacing: 1px;
# 	background: url(../images/menu_shadow.png) no-repeat left bottom;
# }
#
# #back_to_top {
# 	background: none;
# }
#
# a#back_to_top span {
# 	background: url("../images/back_to_top_arrow2.png");
# 	display: block;
# 	width: 11px;
# 	height: 18px;
# 	position: absolute;
# 	left: 50%;
# 	margin-left: -6px;
# 	bottom: 0;
# 	transition: all .3s ease-in-out;
# 	-o-transition: all .3s ease-in-out;
# 	-moz-transition: all .3s ease-in-out;
# 	-webkit-transition: all .3s ease-in-out;
# 	/* color: black; */
# }
#
# .post .post_wrapper .desc {
# 	float: left;
# 	width: 47%;
# 	margin-left: 0%;
# 	padding-top: 0px;
# }
#
# .post_wrapper p {
#     display: none;
# }
#
# .post_title {
#     font-size: 13px;
#     height: 20px;
#     margin: 2px;
#     padding: 0px 0;
#     margin-bottom: 2px !important;
# }
#
# .post {
# 	padding-bottom: 0px;
# 	border-bottom-width: 0px;
# 	border-style: none;
# }
#
# .section_wrapper .column {
# 	margin: 0 0 0px;
# }
#
# .post_title {
# 	font-size: 12px;
# 	line-height: 14px;
# 	padding-bottom: 15px;
# }
#
# .column.one-second {
# margin-right:20px;
# }
#
# table th, table td {
# 	padding: 10px;
# 	text-align: center;
# 	border-width: 0px;
# 	border-style: solid;
# }
#
# <!-- @media only screen and (max-width: 767px)  -->
# .section_wrapper .column, .container .column,  .sections_group, .four.columns {
# 	margin: 0;
# 	width: 85% !important;
# 	clear: both;
# }
# .section {
# 	clear: both;
# 	padding: 0px;
# 	margin: 0px;
# 	/* margin-left: 0px; */
# }
#
#
# .the_content pre {
# 	margin-bottom: 20px;
# 	margin-left: -75px;
# 	margin-top: -50px;
# }
#
# a {
#     color: #144389;
# }
#
# #Header .logo {
# 	position: static;
# 	float: left;
# 	width: 100%;
# 	text-align: left;
# 	margin-left: 8%;
# 	padding-top: 25px;
# }
#
# #Header a.responsive-menu-toggle {
# 	top: 0px;
# 	left: auto;
# 	left: 0;
# }
#
# #Header .social {
# 	z-index: 203;
# 	position: absolute;
# 	right: 0;
# 	top: 0;
# 	margin-right: 2%;
# }
#
# .social li a {
# 	font-size: 30px;
# 	color: #467e9f;
# 	width: 32px;
# 	height: 30px;
# 	line-height: 30px;
# 	padding-top: 0px;
# }
#
#
# #Header .menu {
# 	margin-left: 3%;
# }
#
# #Subheader ul.breadcrumbs {
# 	float: right;
# 	margin-right: 1%;
# 	overflow: hidden;
# 	text-align: right;
# 	font-size: 13px;
# 	/* display: none; */
# }
#
# #menu-footer a {
# 	color: white;
# }
#
# #Footer {
# 	font-size: 95%;
# 	background-color: gray;
# }
#
#
# .widget_nav_menu ul li a, .widget_meta ul li a, .widget_categories ul li a,
#
# .widget_archive ul li
#
# a, .widget_mfn_menu ul li a {
# 	background: none;
# 	color: white;
# }
#
# .widget_nav_menu ul li a, .widget_meta ul li a, .widget_categories ul li a,
#
# .widget_archive ul li
#
# a, .widget_mfn_menu ul li a {
# 	background: none;
# 	color: white;
# 	font-weight: bold;
# }
#
# a.button, a.tp-button, button, input[type="submit"], input[type="reset"],
#
# input[type="button"] {
# 	display: inline-block;
# 	padding: 10px;
# 	font-size: 14px;
# 	-webkit-border-radius: 0px;
# 	border-radius: 5px;
# 	display: block;
# 	background-color: #467e9f;
# 	height: 30px;
# 	padding: 10px;
# 	font: inherit;
# 	box-sizing: content-box;
# 	-webkit-box-sizing: content-box;
# 	-moz-box-sizing: content-box;
# 	width: 100px;
# }
#
#
# @media (max-width: 767px) {
# #Header .language_add {
# 	display: none;
# }
# }
#
# @media (min-width: 768px) and max-width: 1199  {
# #Header .language_add {
# 	float: right;
# 	margin-left: 8%;
# 	margin-top: -10%;
# }
# }
#
# @media (min-width: 1200px)  {
# #Header .language_add {
# 	float: right;
# 	margin-right: 0;
# 	margin-top: 7%;
# }
# }
#
# @media (min-width: 768px) and (max-width: 1199px) {
# #Header #searchform {
# 	padding: 50px 50px;
# }
# }
#
# #Header .menu li ul {
# 	position: absolute;
# 	left: 0px;
# 	top: 60px;
# 	z-index: 205;
# 	margin: 0;
# 	display: none;
# 	background: #467e9f;
# }
#
# #Header .menu li ul li a {
# 	padding: 3px 3px;
# 	font-size: 12px;
# 	display: block;
# 	border-bottom-width: 1px;
# 	border-style: solid;
# 	color: white;
# }
#
# @media (max-width: 767px) {
# #Header .language_add {
# 	display: none;
# }
# }
#
# @media (min-width: 768px) and max-width: 1199  {
# #Header .language_add {
# 	float: right;
# 	margin-left: 8%;
# 	margin-top: -10%;
# }
# }
#
# @media (min-width: 1200px)  {
# #Header .language_add {
# 	float: right;
# 	margin-right: 0;
# 	margin-top: 7%;
# }
# }
#
# @media (min-width: 768px) and (max-width: 1199px) {
# #Header #searchform {
# 	padding: 45px 30px;
# 	padding-bottom: 5px;
# }
# }
#
#
# @media (max-width: 767px) {
# .section_wrapper, .container, .four.columns {
#     width: 95% !important;
# }
# }
#
# @media (max-width: 767px) {
# #Header .logo {
#     position: static;
#     float: left;
#     width: 100%;
#     text-align: left;
#     margin-left: 0%;
#     padding-top: 25px;
# }
# }
#
# #Header .menu li ul {
# 	position: absolute;
# 	left: 0px;
# 	top: 60px;
# 	z-index: 205;
# 	margin: 0;
# 	display: none;
# 	background: #467e9f;
# }
#
# .menu-clean #Header .menu > li > a {
# 	padding: 0 9px;
# 	color: #ffffff;
# }
#
# @media (min-width: 1000px) {
# #Header .contactdist {
# 	z-index: 203;
# 	position: absolute;
# 	float: right;
# 	top: 8%;
# 	right: 20%;
# }
# }
#
# @media (max-width: 999px) {
# #Header .contactdist {
# 	display:none;
# }
# }
#
# #Header .contact_details, #Header .language, #Header #searchform {
# 	float: right;
# 	padding: 30px 20px;
# 	border-right: 0px solid rgba(0, 0, 0, .05);
# }
#
# @media only screen and (max-width: 767px) {
# #Header .addons #searchform {
# 	padding: 0;
# 	float: right;
# 	margin-right: 15px;
# 	margin-top: 30px;
# }
# }
#
# .section {
# 	clear: both;
# 	padding: 0px;
# 	margin: 0px;
# 	/* margin-left: 0px; */
# 	padding-bottom: 10px;
# }
#
# .col {
# 	background: white;
# }
#
# .col {
#   background: rgba(204, 204, 204, 0.85);
# }
#
# /*  SECTIONS  */
# .section {
# 	clear: both;
# 	padding: 0px;
# 	margin: 0px;
# }
#
# .section .section .col {
#   margin-top: 0;
#   margin-bottom: 0;
# }
#
# /*  COLUMN SETUP  */
# .col {
# 	display: block;
# 	float:left;
# 	margin: 1% 0 1% 1%;
# }
# .col:first-child { margin-left: 0; }
#
# .span_1_of_1 {
# 	width: 100%;
# 	margin: 0;
# 	padding: 0;
# 	background-color: #467e9f;
# }
#
#
# /*  GROUPING  */
# .group:before,
# .group:after {
# 	content:"";
# 	display:table;
# }
# .group:after {
# 	clear:both;
# }
#
#
# /*  GRID OF FIVE  */
# .span_5_of_5 {
# 	width: 100%;
# }
# .span_4_of_5 {
# 	width: 79.8%;
# }
# .span_3_of_5 {
# 	width: 59.6%;
# }
# .span_2_of_5 {
# 	width: 39.4%;
# }
# .span_1_of_5 {
# 	width: 19.2%;
# }
#
# /*  GRID OF SIX  */
# .span_6_of_6 {
# 	width: 100%;
# }
#
# .span_5_of_6 {
#   	width: 83.16%;
# }
#
# .span_4_of_6 {
#   	width: 66.33%;
# }
#
# .span_3_of_6 {
#   	width: 49.5%;
# }
#
# .span_2_of_6 {
#   	width: 32.66%;
# }
#
# .span_1_of_6 {
#   	width: 15.83%;
# }
#
# /*  GO FULL WIDTH AT LESS THAN 480 PIXELS */
#
# @media only screen and (max-width: 480px) {
# 	.col {
# 		margin: 1% 0 1% 0%;
# 	}
# }
#
# @media only screen and (max-width: 480px) {
# 	.span_5_of_5 {
# 		width: 100%;
# 	}
# 	.span_4_of_5 {
# 		width: 100%;
# 	}
# 	.span_3_of_5 {
# 		width: 100%;
# 	}
# 	.span_2_of_5 {
# 		width: 100%;
# 	}
# 	.span_1_of_5 {
# 		width: 100%;
# 	}
#
#   .span_6_of_6 {
# 		width: 100%;
# 	}
# 	.span_5_of_6 {
# 		width: 100%;
# 	}
# 	.span_4_of_6 {
# 		width: 100%;
# 	}
# 	.span_3_of_6 {
# 		width: 100%;
# 	}
# 	.span_2_of_6 {
# 		width: 100%;
# 	}
# 	.span_1_of_6 {
# 		width: 100%;
# 	}
# }
#
# input[type="text"], input[type="password"], input[type="email"],
#
# input[type="tel"], textarea, select {
# 	border: 0;
# 	padding: 5px 10px;
# 	outline: none;
# 	margin: 0;
# 	width: 230px;
# 	max-width: 100%;
# 	display: block;
# 	margin-bottom: 10px;
# 	font-size: 12px;
# 	-webkit-border-radius: 3px;
# 	border-radius: 3px;
# 	-webkit-box-shadow: inset 3px 3px 3px rgba(0, 0, 0, 0.05);
# 	box-shadow: inset 3px 3px 3px rgba(0, 0, 0, 0.05);
# 	background-image: url("../images/pattern_form.png");
# }
#
# .widget > h3 {
# 	margin-bottom: 15px;
# 	text-transform: uppercase;
# 	letter-spacing: 2px;
# 	font-size: 14px;
# 	line-height: 19px;
# 	padding-left: 0px;
# 	bullet-style: none;
# }
#
# .archive .post {
#      display:inline-block;
#      vertical-align:top;
#      padding:1.25%;
#      margin:1.25%;
#      min-height:100px;
#      background-color:#ffffff;
# }
#
# .post_photo .photo_wrapper {
# 	padding: 5px;
# 	border-width: 0px;
# 	border-style: solid;
# 	margin-bottom: 7px;
# 	line-height: 0;
# }
#
# .post_navigation {
# 	overflow: hidden;
# 	margin: 0px 1% 20px !important;
# 	padding-bottom: 15px;
# 	border-bottom-width: 0px;
# 	border-style: solid;
# 	font-size: 13px;
# }
#
# .latest_posts_wrapper .photo {
# 	padding: 10px;
# 	border-width: 0px;
# 	border-style: solid;
# 	margin-bottom: 7px;
# 	line-height: 0;
# }
#
# .widgets_wrapper {
# 	padding: 30px 6% 15px;
# }
#
# label, legend {
# 	display: block;
# 	font-size: 90%;
# }
#
# a.button, a.tp-button, button, input[type="submit"], input[type="reset"],
#
# input[type="button"] {
# 	margin-top: 10px;
# }
#
# .section-post-about .latest_posts_wrapper.related {
# 	padding: 0;
# 	margin-bottom: 0;
# 	display: none;
# }
#
# #fullResImage img {
#   width:200%;
#   height:auto;
# }
#
# .col {
# 	background: white;
# }
#
# h3 {
# 	margin: auto;
# 	font-size: 125%;
# }
#
# .menu-clean #Header #menu {
# 	z-index: 9999;
#        font-size:small;
# }
#
# .menu-clean #Header .menu > li > a {
# 	padding: 0 17px;
# 	color: #ffffff;
# }
#
# @media (min-width: 768px) and (max-width: 1279px) {
# .menu-clean #Header .menu > li > a {
# 	padding: 0 9px;
# 	color: #ffffff;
# }
# }
#
# #Header .contactdist {
# 	z-index: 203;
# 	position: absolute;
# 	float: right;
# 	top: 5%;
# 	right: 20%;
# }
#
# #mfn-rev-slider { min-height:200px; }
#
# @media only screen and (max-width: 480px) {
# #mfn-rev-slider { min-height:200px; }
# }
#
# @media only screen and (max-width: 959px) {
# #Header #menu ul li.submenu .menu-toggle {
# 	display: none;
# }
#
# #responsive-form{
# 	max-width:600px /*-- change this to get your desired form width --*/;
# 	margin:0 auto;
#         width:100%;
# }
# .form-row{
# 	width: 100%;
# }
# .column-half, .column-full{
# 	float: left;
# 	position: relative;
# 	padding: 0.65rem;
# 	width:100%;
# 	-webkit-box-sizing: border-box;
#         -moz-box-sizing: border-box;
#         box-sizing: border-box
# }
# .clearfix:after {
# 	content: "";
# 	display: table;
# 	clear: both;
# }
#
# /**---------------- Media query ----------------**/
# @media only screen and (min-width: 48em) {
# 	.column-half{
# 		width: 50%;
# 	}
# }
#
# .wpcf7 input[type="text"], .wpcf7 input[type="email"], .wpcf7 textarea {
# 	width: 100%;
# 	padding: 8px;
# 	border: 1px solid #ccc;
# 	border-radius: 3px;
# 	-webkit-box-sizing: border-box;
# 	 -moz-box-sizing: border-box;
# 	      box-sizing: border-box
# }
# .wpcf7 input[type="text"]:focus{
# 	background: #fff;
# }
# .wpcf7-submit{
# 	float: right;
# 	background: #CA0002;
# 	color: #fff;
# 	text-transform: uppercase;
# 	border: none;
# 	padding: 8px 20px;
# 	cursor: pointer;
# }
# .wpcf7-submit:hover{
# 	background: #ff0000;
# }
# span.wpcf7-not-valid-tip{
# 	text-shadow: none;
# 	font-size: 12px;
# 	color: #fff;
# 	background: #ff0000;
# 	padding: 5px;
# }
# div.wpcf7-validation-errors {
# 	text-shadow: none;
# 	border: transparent;
# 	background: #f9cd00;
# 	padding: 5px;
# 	color: #9C6533;
# 	text-align: center;
# 	margin: 0;
# 	font-size: 12px;
# }
# div.wpcf7-mail-sent-ok{
# 	text-align: center;
# 	text-shadow: none;
# 	padding: 5px;
# 	font-size: 12px;
# 	background: #59a80f;
# 	border-color: #59a80f;
# 	color: #fff;
# 	margin: 0;
# }
#
# .one_half {
# 	width: 45%;
# 	padding-right: 4%;
# }
#
# /*** Works on common browsers ***/
# ::selection {
#     background-color: #352e7e;
#     color: #fff;
# }
#
# /*** Mozilla based browsers ***/
# ::-moz-selection {
#     background-color: #352e7e;
#     color: #fff;
# }
#
# /***For Other Browsers ***/
# ::-o-selection {
#     background-color: #352e7e;
#     color: #fff;
# }
#
# ::-ms-selection {
#     background-color: #352e7e;
#     color: #fff;
# }
#
# /*** For Webkit ***/
# ::-webkit-selection {
#     background-color: #352e7e;
#     color: #fff;
# }
#
# .alignleft2 {
#     float: left;
#     margin: 0px 0px 0px 0px;
#     margin-left: -10px;
# width:120%;
# }
#
# @media (max-width: 767px) {
# .alignleft2 {
# 	display: none;
# }
# }
#
# .set-height {
# 	min-height: 70px;
# }
# </style>
# <!--[if lt IE 9]>
# <script src="http://html5shiv.googlecode.com/svn/trunk/html5.js"></script>
# <![endif]-->
# <link href="http://danielsmith.com/wp-content/uploads/2017/11/cropped-DS_icon_512-32x32.jpg" rel="icon" sizes="32x32"/>
# <link href="http://danielsmith.com/wp-content/uploads/2017/11/cropped-DS_icon_512-192x192.jpg" rel="icon" sizes="192x192"/>
# <link href="http://danielsmith.com/wp-content/uploads/2017/11/cropped-DS_icon_512-180x180.jpg" rel="apple-touch-icon"/>
# <meta content="http://danielsmith.com/wp-content/uploads/2017/11/cropped-DS_icon_512-270x270.jpg" name="msapplication-TileImage"/>
# </head>
# <!-- body -->
# <body class="post-template-default single single-post postid-2035 single-format-standard with_aside aside_right color-custom layout-full-width menu-clean">
# <!-- #Wrapper -->
# <div id="Wrapper">
# <!-- .header_placeholder 4sticky  -->
# <div class="header_placeholder"></div>
# <!-- #Header -->
# <header id="Header">
# <!-- .contactdist -->
# <div class="contactdist">
# <a href="http://www.danielsmith.com/contact-us/">Contact Us
# 				</a>
# </div>
# <div class="container">
# <div class="column one">
# <!-- .social -->
# <div class="social">
# <ul>
# <li class="facebook"><a href="https://www.facebook.com/DanielSmithArtSupplies" target="_blank" title="Facebook"><img src="/wp-content/uploads/social_f3.jpg" width="24px"/></a></li> <li class="twitter"><a href="https://twitter.com/danielsmith_art?lang=en" target="_blank" title="Twitter"><img src="/wp-content/uploads/social_t3.jpg" width="24px"/></a></li> <li class="youtube"><a href="https://www.youtube.com/channel/UC7EIql73Ld2MbqNHyXr4TYg" target="_blank" title="YouTube"><img src="/wp-content/uploads/social_y3.jpg" width="24px"/></a></li> <li class="linked_in"><a href="https://www.instagram.com/danielsmithartistsmaterials/" target="_blank" title="Instagram"><img src="/wp-content/uploads/social_i3.jpg" width="24px"/></a></li> <li class="pinterest"><a href="https://www.pinterest.com/danielsmithcom/" target="_blank" title="Pinterest"><img src="/wp-content/uploads/social_p3.jpg" width="24px"/></a></li> </ul>
# </div>
# <div class="addons">
# <form action="http://danielsmith.com/" id="searchform" method="get">
# <span class="ico"></span>
# <input class="field" id="s" name="s" placeholder="Enter your search" type="text"/>
# <input class="submit" style="display:none;" type="submit" value=""/>
# </form>
# <div class="contact_details">
# <p class="text"></p>
# <div class="default-language-en" id="google_language_translator"></div> </div>
# </div>
# <!-- .logo -->
# <div class="logo">
# <a href="http://danielsmith.com" id="logo" title="DANIEL SMITH">
# <img alt="DANIEL SMITH" class="scale-with-grid" src="http://danielsmith.com/wp-content/themes/brandon/images/logo.png"/>
# </a>
# </div>
# <!-- #menu -->
# <nav class="menu-top-nav-container" id="menu"><ul class="menu" id="menu-top-nav"><li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-home" id="menu-item-1766"><a href="http://danielsmith.com/"><i class="fa-home"></i></a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-has-children" id="menu-item-2435"><a href="http://danielsmith.com/about-us/">About Us</a>
# <ul class="sub-menu">
# <li class="menu-item menu-item-type-post_type menu-item-object-page" id="menu-item-6395"><a href="http://danielsmith.com/about-us/opportunities/">Job Opportunities</a></li>
# </ul>
# </li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page" id="menu-item-2480"><a href="http://danielsmith.com/featured-artists/">Artists Love DANIEL SMITH</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-has-children" id="menu-item-1765"><a href="http://danielsmith.com/watercolor/">Watercolor</a>
# <ul class="sub-menu">
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category" id="menu-item-2376"><a href="http://danielsmith.com/category/wc15ml/">Watercolor 15ml</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category current-post-ancestor current-menu-parent current-post-parent" id="menu-item-2378"><a href="http://danielsmith.com/category/wc5ml/">Watercolor 5ml</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page" id="menu-item-2500"><a href="http://danielsmith.com/watercolor-sticks/">Watercolor Sticks</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-post" id="menu-item-7638"><a href="http://danielsmith.com/daniel-smith-hand-poured-watercolor-half-pan-sets/">Watercolor Half Pan Sets</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page" id="menu-item-2497"><a href="http://danielsmith.com/watercolor-sets/">Watercolor Sets</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page" id="menu-item-2505"><a href="http://danielsmith.com/watercolor-dot-cards/">Watercolor Dot Cards</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page" id="menu-item-2513"><a href="http://danielsmith.com/daniel-smith-primatek-watercolors/">PrimaTek Watercolors</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page" id="menu-item-2579"><a href="http://danielsmith.com/daniel-smith-luminescent-watercolor/">Luminescent Watercolors</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page" id="menu-item-2578"><a href="http://danielsmith.com/watercolor-ground/">Watercolor Ground</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-post" id="menu-item-2580"><a href="http://danielsmith.com/watercolor-masking-fluid/">Watercolor Masking Fluid</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page" id="menu-item-2586"><a href="http://danielsmith.com/daniel-smith-walnut-ink/">Walnut Ink</a></li>
# </ul>
# </li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-has-children" id="menu-item-1764"><a href="http://danielsmith.com/oil-color/">Oil Color</a>
# <ul class="sub-menu">
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category" id="menu-item-2357"><a href="http://danielsmith.com/category/ooil/">Original Oil</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page" id="menu-item-2647"><a href="http://danielsmith.com/primatek-original-oils/">PrimaTek Original Oils</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page" id="menu-item-2658"><a href="http://danielsmith.com/original-oil-mediums/">Original Oil Mediums</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category" id="menu-item-2358"><a href="http://danielsmith.com/category/wsoil/">Water Soluble Oil</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page" id="menu-item-2674"><a href="http://danielsmith.com/water-soluble-mediums/">Water Soluble Mediums</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page" id="menu-item-2673"><a href="http://danielsmith.com/daniel-smith-acrylic-gesso/">Gesso</a></li>
# </ul>
# </li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page" id="menu-item-10531"><a href="http://danielsmith.com/2020-trade-shows/">2020 Trade Shows</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-has-children" id="menu-item-2548"><a href="http://danielsmith.com/blogs/">Blogs</a>
# <ul class="sub-menu">
# <li class="menu-item menu-item-type-post_type menu-item-object-page" id="menu-item-6263"><a href="http://danielsmith.com/blog-index/">Blog Index</a></li>
# </ul>
# </li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-has-children" id="menu-item-2560"><a href="http://danielsmith.com/brochures-and-color-charts/">Product Resources</a>
# <ul class="sub-menu">
# <li class="menu-item menu-item-type-post_type menu-item-object-page" id="menu-item-2559"><a href="http://danielsmith.com/brochures-and-color-charts/">Brochures and Color Charts</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page" id="menu-item-2558"><a href="http://danielsmith.com/video-the-art-of-making-paint/">Video: The Art of Making Paint</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page" id="menu-item-2557"><a href="http://danielsmith.com/color-finder/">Color Finder</a></li>
# </ul>
# </li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom" id="menu-item-2465"><a href="https://www.youtube.com/channel/UC7EIql73Ld2MbqNHyXr4TYg">Videos</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-has-children" id="menu-item-2752"><a href="http://danielsmith.com/retailers/">Retailers</a>
# <ul class="sub-menu">
# <li class="menu-item menu-item-type-post_type menu-item-object-page" id="menu-item-6318"><a href="http://danielsmith.com/retailers/online-retailers/">Online Retailers</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page" id="menu-item-6319"><a href="http://danielsmith.com/retailers/">Find a Retailer</a></li>
# </ul>
# </li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom" id="menu-item-1768"><a href="http://danielsmith.com/shopdanielsmith-is-now-closed/">SHOP NOW</a></li>
# </ul></nav>
# <a class="responsive-menu-toggle" href="#"><i class="fa-bars"></i></a>
# </div>
# </div>
# </header>
# <div id="Subheader"><div class="container"><div class="column one"><h1 class="title">Undersea Green 5ml Tube – DANIEL SMITH Extra Fine Watercolor</h1><ul class="breadcrumbs"><li><i class="fa-home"></i> <a href="http://danielsmith.com">Home</a> <span>/</span></li><li><a href="http://danielsmith.com/products/">Products</a> <span>/</span></li><li><a href="http://danielsmith.com/category/product/">All</a> <span>/</span></li><li><a href="http://danielsmith.com/undersea-green-5ml-tube-daniel-smith-extra-fine-watercolor/?html.parser">Undersea Green 5ml Tube – DANIEL SMITH Extra Fine Watercolor</a></li></ul></div></div></div>
# <!-- #Content -->
# <div id="Content">
# <div class="content_wrapper clearfix">
# <!-- .sections_group -->
# <div class="sections_group">
# <div class="section section-post-header">
# <div class="section_wrapper clearfix">
# <div class="column one post_navigation">
# <a class="prev_post post_control" href="http://danielsmith.com/green-gold-5ml-tube-daniel-smith-extra-fine-watercolor/"><i class="fa-angle-left"></i>Previous product</a>
# <a class="next_post post_control" href="http://danielsmith.com/perylene-green-5ml-tube-daniel-smith-extra-fine-watercolor/">Next product<i class="fa-angle-right"></i></a>
# </div>
# <div class="column one post_header no-meta">
# <div class="post_photo">
# <div class="photo_wrapper hover-mask">
# <a href="http://danielsmith.com/wp-content/uploads/284610109_112817.jpg" rel="prettyPhoto"><img alt="" class="scale-with-grid wp-post-image" height="400" sizes="(max-width: 400px) 100vw, 400px" src="http://danielsmith.com/wp-content/uploads/284610109_112817.jpg" srcset="http://danielsmith.com/wp-content/uploads/284610109_112817.jpg 400w, http://danielsmith.com/wp-content/uploads/284610109_112817-150x150.jpg 150w, http://danielsmith.com/wp-content/uploads/284610109_112817-146x146.jpg 146w, http://danielsmith.com/wp-content/uploads/284610109_112817-50x50.jpg 50w, http://danielsmith.com/wp-content/uploads/284610109_112817-380x380.jpg 380w, http://danielsmith.com/wp-content/uploads/284610109_112817-90x90.jpg 90w, http://danielsmith.com/wp-content/uploads/284610109_112817-80x80.jpg 80w, http://danielsmith.com/wp-content/uploads/284610109_112817-42x42.jpg 42w" width="400"/><span class="ico"><i class="fa-eye"></i></span></a> </div>
# </div>
# </div>
# </div>
# </div>
# <div class="section section-post-content post-2035 post type-post status-publish format-standard has-post-thumbnail hentry category-product category-wc5ml lightfastness-all lightfastness-lightfastness-i-excellent granulation-all granulation-granulation-granulating staining-all staining-staining-3-medium-staining transparency-all transparency-transparency-semi-transparent colorfamily-all colorfamily-green type-all" id="post-2035">
# <div class="section the_content"><div class="section_wrapper"><div class="the_content_wrapper"><p>An artist’s favorite, this exciting medium to high staining green blends French Ultramarine with Quinacridone Gold.  The inorganic, sedimentary French Ultramarine settles and granulates while the organic, transparent Quinacridone Gold floats into a golden halo.  Concentrated, this will remind you of warm sea kelp.  Apply with Moonglow, Ultramarines and Quinacridone mixtures to color-coordinate and lend atmosphere to various passages.  Undersea Green is beautiful touched damp or drybrushed with Interference Gold.  Use Undersea green into autumn leaf paintings.</p>
# <p>SKU: 284610109<br/>
# Pigment: PB 29, PO 48, PY 150 | Series: 1<br/>
# Lightfastness: I – Excellent<br/>
# Transparency: Semi-Transparent<br/>
# Staining: 3-Medium Staining<br/>
# Granulation: Granulating</p>
# <p><a href="https://www.dropbox.com/s/3ovuz33tr7um6o3/284600000-284640999%20Extra%20Fine%20Watercolor%20SDS%20Guidelines%28English%29.pdf?dl=1">MSDS</a></p>
# </div></div></div></div>
# <div class="section section-post-about">
# <div class="section_wrapper clearfix">
# </div>
# </div>
# <div class="section section-post-footer">
# <div class="section_wrapper clearfix">
# <div class="column one comments">
# <div id="comments">
# <p class="nocomments">Comments are closed.</p>
# </div><!-- #comments -->
# </div>
# </div>
# </div> </div>
# <!-- .four-columns - sidebar -->
# <div class="four columns">
# <div class="widget-area clearfix">
# <aside class="widget widget_text" id="text-6"> <div class="textwidget"><p><a href="http://www.danielsmith.com/retailers/"><img border="0" src="http://www.danielsmith.com/wp-content/uploads/retailerbutton.jpg"/></a></p>
# </div>
# </aside> </div>
# </div>
# </div>
# </div>
# </div>
# <!-- #Footer -->
# <footer class="clearfix" id="Footer">
# <div class="footer_line">
# <div class="container">
# <div class="line line_1"></div>
# <div class="line line_2"></div>
# <div class="line line_3"></div>
# <div class="line line_4"></div>
# </div>
# </div>
# <div class="widgets_wrapper">
# <div class="container">
# <div class="one-fourth column"><aside class="widget widget_nav_menu" id="nav_menu-10"><div class="menu-footer-1-container"><ul class="menu" id="menu-footer-1"><li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-1771" id="menu-item-1771"><a href="http://danielsmith.com/watercolor/">DANIELSMITH WATERCOLOR PRODUCTS</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-2622" id="menu-item-2622"><a href="http://danielsmith.com/category/wc15ml/">Watercolor 15ml</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category current-post-ancestor current-menu-parent current-post-parent menu-item-2623" id="menu-item-2623"><a href="http://danielsmith.com/category/wc5ml/">Watercolor 5ml</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-2624" id="menu-item-2624"><a href="http://danielsmith.com/category/watercolor-stick/">Watercolor Stick</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-post menu-item-7639" id="menu-item-7639"><a href="http://danielsmith.com/daniel-smith-hand-poured-watercolor-half-pan-sets/">Watercolor Half Pan Sets</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-2630" id="menu-item-2630"><a href="http://danielsmith.com/watercolor-sets/">Watercolor Sets</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-2628" id="menu-item-2628"><a href="http://danielsmith.com/daniel-smith-primatek-watercolors/">PrimaTek Watercolors</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-2627" id="menu-item-2627"><a href="http://danielsmith.com/daniel-smith-luminescent-watercolor/">Luminescent Watercolors</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-2626" id="menu-item-2626"><a href="http://danielsmith.com/watercolor-ground/">Watercolor Ground</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-2629" id="menu-item-2629"><a href="http://danielsmith.com/watercolor-dot-cards/">Watercolor Dot Cards</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-post menu-item-2631" id="menu-item-2631"><a href="http://danielsmith.com/watercolor-masking-fluid/">Masking Fluid</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-2625" id="menu-item-2625"><a href="http://danielsmith.com/daniel-smith-walnut-ink/">Walnut Ink</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-10530" id="menu-item-10530"><a href="http://danielsmith.com/2020-trade-shows/">2020 Trade Shows</a></li>
# </ul></div></aside></div><div class="one-fourth column"><aside class="widget widget_nav_menu" id="nav_menu-7"><div class="menu-footer-2-container"><ul class="menu" id="menu-footer-2"><li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-2633" id="menu-item-2633"><a href="http://danielsmith.com/oil-color/">DANIEL SMITH OIL</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-2634" id="menu-item-2634"><a href="http://danielsmith.com/category/ooil/">Original Oil</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-2648" id="menu-item-2648"><a href="http://danielsmith.com/primatek-original-oils/">PrimaTek Original Oils</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-2657" id="menu-item-2657"><a href="http://danielsmith.com/original-oil-mediums/">Original Oil Mediums</a></li>
# <li class="menu-item menu-item-type-taxonomy menu-item-object-category menu-item-2635" id="menu-item-2635"><a href="http://danielsmith.com/category/wsoil/">Water Soluble Oil</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-2676" id="menu-item-2676"><a href="http://danielsmith.com/water-soluble-mediums/">Water Soluble Mediums</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-2675" id="menu-item-2675"><a href="http://danielsmith.com/daniel-smith-acrylic-gesso/">Gesso</a></li>
# </ul></div></aside></div><div class="one-fourth column"><aside class="widget widget_nav_menu" id="nav_menu-8"><div class="menu-footer-3-container"><ul class="menu" id="menu-footer-3"><li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-2637" id="menu-item-2637"><a href="http://danielsmith.com/about-us/">ABOUT DANIEL SMITH</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-2638" id="menu-item-2638"><a href="http://danielsmith.com/about-us/">About Us</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-1772" id="menu-item-1772"><a href="http://danielsmith.com/retailers/">Find a Retailer</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-2639" id="menu-item-2639"><a href="http://danielsmith.com/blogs/">Blogs</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-2640" id="menu-item-2640"><a href="http://danielsmith.com/featured-artists/">Artists Love DANIEL SMITH</a></li>
# <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-4325" id="menu-item-4325"><a href="http://danielsmith.com/contact-us/">Contact Us &amp; Sign Up for our Newsletter</a></li>
# </ul></div></aside></div><div class="one-fourth column"><aside class="widget widget_nav_menu" id="nav_menu-9"><div class="menu-footer-4-container"><ul class="menu" id="menu-footer-4"><li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-1769" id="menu-item-1769"><a href="http://danielsmith.com/shopdanielsmith-is-now-closed/">SHOP ONLINE (USA ONLY)</a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-2642" id="menu-item-2642"><a href="http://danielsmith.com/shopdanielsmith-is-now-closed/">Shop Now</a></li>
# </ul></div></aside></div>
# </div>
# </div>
# <div class="footer_menu">
# <div class="container">
# <div class="copyright">
# 				© 2020 DANIEL SMITH. All Rights Reserved. <a href="http://muffingroup.com" rel="nofollow" target="_blank">Muffin group</a> </div>
# </div>
# </div>
# <a href="#" id="back_to_top"><span></span></a>
# </footer>
# <!-- wp_footer() -->
# <div class="size18" id="flags" style="display:none"><ul class="ui-sortable" id="sortable"><li id="English"><a class="nturl notranslate en flag united-states" href="#" title="English"></a></li><li id="French"><a class="nturl notranslate fr flag French" href="#" title="French"></a></li><li id="German"><a class="nturl notranslate de flag German" href="#" title="German"></a></li><li id="Russian"><a class="nturl notranslate ru flag Russian" href="#" title="Russian"></a></li><li id="Spanish"><a class="nturl notranslate es flag Spanish" href="#" title="Spanish"></a></li></ul></div><div id="glt-footer"></div><script>function GoogleLanguageTranslatorInit() { new google.translate.TranslateElement({pageLanguage: 'en', includedLanguages:'en,fr,de,ru,es', layout: google.translate.TranslateElement.InlineLayout.HORIZONTAL, autoDisplay: false}, 'google_language_translator');}</script><script type="text/javascript">
# /* <![CDATA[ */
# var wpcf7 = {"apiSettings":{"root":"http:\/\/danielsmith.com\/wp-json\/contact-form-7\/v1","namespace":"contact-form-7\/v1"},"cached":"1"};
# /* ]]> */
# </script>
# <script src="http://danielsmith.com/wp-content/plugins/contact-form-7/includes/js/scripts.js?ver=5.1.6" type="text/javascript"></script>
# <script type="text/javascript">
# /* <![CDATA[ */
# var PT_CV_PUBLIC = {"_prefix":"pt-cv-","page_to_show":"5","_nonce":"86c8657671","is_admin":"","is_mobile":"","ajaxurl":"http:\/\/danielsmith.com\/wp-admin\/admin-ajax.php","lang":"","loading_image_src":"...\"};
# var PT_CV_PAGINATION = {"links":{"page_1":"http:\/\/danielsmith.com\/undersea-green-5ml-tube-daniel-smith-extra-fine-watercolor\/?html_parser","page_n":"http:\/\/danielsmith.com\/undersea-green-5ml-tube-daniel-smith-extra-fine-watercolor\/?_page=_CVNUMBER_&html_parser"},"first":"\u00ab","prev":"\u2039","next":"\u203a","last":"\u00bb","goto_first":"Go to first page","goto_prev":"Go to previous page","goto_next":"Go to next page","goto_last":"Go to last page","current_page":"Current page is","goto_page":"Go to page"};
# /* ]]> */
# </script>
# <script src="http://danielsmith.com/wp-content/plugins/content-views-query-and-display-post-page/public/assets/js/cv.js?ver=2.3.1" type="text/javascript"></script>
# <script src="http://danielsmith.com/wp-content/plugins/google-language-translator/js/scripts.js?ver=6.0.4" type="text/javascript"></script>
# <script src="//translate.google.com/translate_a/element.js?cb=GoogleLanguageTranslatorInit" type="text/javascript"></script>
# <script src="http://danielsmith.com/wp-includes/js/jquery/ui/core.min.js?ver=1.11.4" type="text/javascript"></script>
# <script src="http://danielsmith.com/wp-includes/js/jquery/ui/widget.min.js?ver=1.11.4" type="text/javascript"></script>
# <script src="http://danielsmith.com/wp-includes/js/jquery/ui/mouse.min.js?ver=1.11.4" type="text/javascript"></script>
# <script src="http://danielsmith.com/wp-includes/js/jquery/ui/sortable.min.js?ver=1.11.4" type="text/javascript"></script>
# <script src="http://danielsmith.com/wp-includes/js/jquery/ui/tabs.min.js?ver=1.11.4" type="text/javascript"></script>
# <script src="http://danielsmith.com/wp-includes/js/jquery/ui/accordion.min.js?ver=1.11.4" type="text/javascript"></script>
# <script src="http://danielsmith.com/wp-content/themes/brandon/js/owl-carousel/owl.carousel.min.js?ver=1.9.4" type="text/javascript"></script>
# <script src="http://danielsmith.com/wp-content/themes/brandon/js/jquery.swiper.min.js?ver=1.9.4" type="text/javascript"></script>
# <script src="http://danielsmith.com/wp-content/themes/brandon/js/jquery.plugins.js?ver=1.9.4" type="text/javascript"></script>
# <script src="http://danielsmith.com/wp-content/themes/brandon/js/mfn.menu.js?ver=1.9.4" type="text/javascript"></script>
# <script src="http://danielsmith.com/wp-content/themes/brandon/js/scripts.js?ver=1.9.4" type="text/javascript"></script>
# <script src="http://danielsmith.com/wp-includes/js/comment-reply.min.js?ver=5.4.1" type="text/javascript"></script>
# <script src="http://danielsmith.com/wp-content/plugins/q2w3-fixed-widget/js/q2w3-fixed-widget.min.js?ver=5.1.9" type="text/javascript"></script>
# <script src="http://danielsmith.com/wp-includes/js/wp-embed.min.js?ver=5.4.1" type="text/javascript"></script>
# <!-- Powered by Orbisius Warning Suppressor | URL: https://orbisius.com/products/wordpress-plugins/orbisius-warning-suppressor/ -->
# </body>
# </html>

# %% [markdown]
# Extract the title

# %%
title = soup.title.string
print(title)
#the title will need to be parsed
# Out:
# Buff Titanium 5ml Tube - DANIEL SMITH Extra Fine Watercolor - DANIEL SMITHDANIEL SMITH

# %% [markdown]
# Get the image

# %%
meta = soup.find(property="og:image")

# %%
print(meta.attrs)
# Out:
# {'property': 'og:image', 'content': 'http://danielsmith.com/wp-content/uploads/284610009_112817.jpg'}

# %%
image_url = meta['content']

# %%
print(image_url)
# Out:
# http://danielsmith.com/wp-content/uploads/284610009_112817.jpg

# %%
#once the title is parsed it can be used to iterate the picname
with open('buff.jpg', 'wb') as handle:
        response = requests.get(image_url, stream=True)

        if not response.ok:
            print (response)

        for block in response.iter_content(1024):
            if not block:
                break

            handle.write(block)

# %%
from PIL import Image

# %%
image = Image.open('buff.jpg')

# %%
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=400x400 at 0x11383ACD0>

# %% [markdown]
# get the pigment information

# %%
info = soup.find_all('p')

# %%
print(info)
# Out:
# [<p class="text"></p>, <p>An artist’s favorite, this exciting medium to high staining green blends French Ultramarine with Quinacridone Gold.  The inorganic, sedimentary French Ultramarine settles and granulates while the organic, transparent Quinacridone Gold floats into a golden halo.  Concentrated, this will remind you of warm sea kelp.  Apply with Moonglow, Ultramarines and Quinacridone mixtures to color-coordinate and lend atmosphere to various passages.  Undersea Green is beautiful touched damp or drybrushed with Interference Gold.  Use Undersea green into autumn leaf paintings.</p>, <p>SKU: 284610109<br/>
# Pigment: PB 29, PO 48, PY 150 | Series: 1<br/>
# Lightfastness: I – Excellent<br/>
# Transparency: Semi-Transparent<br/>
# Staining: 3-Medium Staining<br/>
# Granulation: Granulating</p>, <p><a href="https://www.dropbox.com/s/3ovuz33tr7um6o3/284600000-284640999%20Extra%20Fine%20Watercolor%20SDS%20Guidelines%28English%29.pdf?dl=1">MSDS</a></p>, <p class="nocomments">Comments are closed.</p>, <p><a href="http://www.danielsmith.com/retailers/"><img border="0" src="http://www.danielsmith.com/wp-content/uploads/retailerbutton.jpg"/></a></p>]

# %%
info[1]
# Out:
# <p>An artist’s favorite, this exciting medium to high staining green blends French Ultramarine with Quinacridone Gold.  The inorganic, sedimentary French Ultramarine settles and granulates while the organic, transparent Quinacridone Gold floats into a golden halo.  Concentrated, this will remind you of warm sea kelp.  Apply with Moonglow, Ultramarines and Quinacridone mixtures to color-coordinate and lend atmosphere to various passages.  Undersea Green is beautiful touched damp or drybrushed with Interference Gold.  Use Undersea green into autumn leaf paintings.</p>

# %%
import re

# %% [markdown]
# All of this needs to be iterated in a function

# %%
pigment = soup.find(string=re.compile("Pigment")).string.strip().split("|")[0]

# %%
pigment
# Out:
# 'Pigment: PB 29, PO 48, PY 150 '

# %%
len(pigment.split(','))
# Out:
# 3

# %%
pigment_split = pigment.strip("\n").split("|")

# %%
pigment_split[0].strip()
# Out:
# 'Pigment: PB 29, PO 48, PY 150'

# %%
light = soup.find(string=re.compile("Lightfastness")).strip()
print(light)
# Out:
# Lightfastness: I – Excellent

# %%
soup.find(string=re.compile("Transparency"))
# Out:
# '\nTransparency: Semi-Opaque'

# %%
soup.find(string=re.compile("Staining"))
# Out:
# '\nStaining: 1-Non-Staining'

# %% [markdown]
# K-means clustering segmentation

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy import ndimage

# %%
image = plt.imread('/Users/macbook/Box/insight_project_data/test_image/Tucan2.jpg')
print(image.shape)
plt.imshow(image)
# Out:
# (731, 1100, 3)

# %%
image
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]]], dtype=uint8)

# %%
image_n = image.reshape(image.shape[0]*image.shape[1], image.shape[2])
image_n.shape
# Out:
# (804100, 3)

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=100, random_state=0).fit(image_n)
image2show = kmeans.cluster_centers_[kmeans.labels_]

# %%
cluster_image.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-6bf5ced8db22> in <module>
# ----> 1 cluster_image.shape
#
# NameError: name 'cluster_image' is not defined

# %%
cluster_image.astype(int)
# Out:
# array([[[ 18,  23,  21],
#         [ 18,  23,  21],
#         [ 18,  23,  21],
#         ...,
#         [ 65,  86,  33],
#         [ 65,  86,  33],
#         [ 65,  86,  33]],
#
#        [[ 18,  23,  21],
#         [ 18,  23,  21],
#         [ 18,  23,  21],
#         ...,
#         [ 65,  86,  33],
#         [ 65,  86,  33],
#         [ 65,  86,  33]],
#
#        [[ 18,  23,  21],
#         [ 18,  23,  21],
#         [ 18,  23,  21],
#         ...,
#         [ 65,  86,  33],
#         [ 65,  86,  33],
#         [ 65,  86,  33]],
#
#        ...,
#
#        [[ 93, 114,  52],
#         [ 93, 114,  52],
#         [ 93, 114,  52],
#         ...,
#         [ 93, 114,  52],
#         [ 93, 114,  52],
#         [ 93, 114,  52]],
#
#        [[ 93, 114,  52],
#         [ 93, 114,  52],
#         [ 93, 114,  52],
#         ...,
#         [ 93, 114,  52],
#         [ 93, 114,  52],
#         [ 93, 114,  52]],
#
#        [[ 93, 114,  52],
#         [ 93, 114,  52],
#         [ 93, 114,  52],
#         ...,
#         [ 93, 114,  52],
#         [ 93, 114,  52],
#         [ 93, 114,  52]]])

# %%
cluster_image = image2show.reshape(image.shape[0], image.shape[1], image.shape[2])
cluster_image.astype(int)
#plt.imshow(cluster_image)
# Out:
# array([[[ 30,  46,  19],
#         [ 30,  46,  19],
#         [ 30,  46,  19],
#         ...,
#         [ 53,  74,  19],
#         [ 53,  74,  19],
#         [ 53,  74,  19]],
#
#        [[ 30,  46,  19],
#         [ 30,  46,  19],
#         [ 30,  46,  19],
#         ...,
#         [ 53,  74,  19],
#         [ 53,  74,  19],
#         [ 53,  74,  19]],
#
#        [[ 30,  46,  19],
#         [ 30,  46,  19],
#         [ 30,  46,  19],
#         ...,
#         [ 53,  74,  19],
#         [ 53,  74,  19],
#         [ 53,  74,  19]],
#
#        ...,
#
#        [[ 87, 109,  50],
#         [ 89, 113,  56],
#         [ 95, 118,  59],
#         ...,
#         [ 81, 104,  57],
#         [ 81, 104,  57],
#         [ 81, 104,  57]],
#
#        [[ 87, 109,  50],
#         [ 89, 113,  56],
#         [ 95, 118,  59],
#         ...,
#         [ 81, 104,  57],
#         [ 81, 104,  57],
#         [ 81, 104,  57]],
#
#        [[ 87, 109,  50],
#         [ 89, 113,  56],
#         [ 95, 118,  59],
#         ...,
#         [ 81, 104,  57],
#         [ 81, 104,  57],
#         [ 81, 104,  57]]])

# %%
int_image = cluster_image.astype(int)

# %%
plt.imshow(int_image)

# %%
plt.savefig('segment_gold', format='jpg')
