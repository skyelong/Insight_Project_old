# %%
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# Page to get all the color names and links to the individual pages with the images
# http://danielsmith.com/category/wc5ml/
#
# four pages, page 2 -4
#
# http://danielsmith.com/category/wc5ml/page/2/
#
# <h4 appears to be the tag for the information

# %%
url = "http://danielsmith.com/category/wc5ml/"

webpage_response = requests.get(url, "html.parser")
soup = BeautifulSoup(webpage_response.content, 'xml')
print(soup)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <!DOCTYPE html>
# <!--[if lt IE 7 ]><html class="ie ie6" lang="en"> <![endif]--><!--[if IE 7 ]><html class="ie ie7" lang="en"> <![endif]--><!--[if IE 8 ]><html class="ie ie8" lang="en"> <![endif]--><!--[if (gte IE 9)|!(IE)]><!--><html lang="en-US"> <!--<![endif]-->
# <!-- head -->
# <head>
# <!-- meta -->
# <meta charset="UTF-8"/>
# <meta content="IE=edge" http-equiv="x-ua-compatible">
# <meta content="width=device-width, initial-scale=1, maximum-scale=1" name="viewport">
# <title>Watercolor 5ml Archives - DANIEL SMITHDANIEL SMITH</title>
# <link href="http://danielsmith.com/wp-content/uploads/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <!-- wp_head() -->
# <script>
# //
# window.mfn_slider_vertical	= { autoplay:10000 	};
# window.mfn_slider_portfolio 	= { autoPlay:0 };
# //
# </script>
# <!-- This site is optimized with the Yoast SEO plugin v13.0 - https://yoast.com/wordpress/plugins/seo/ -->
# ...

# %%
meta = soup.h4

# %%
meta
# Out:
# <h4 class="post_title"><a href="http://danielsmith.com/pearlescent-white-5ml-tube-daniel-smith-luminescent-watercolor/">Pearlescent White 5ml Tube – DANIEL SMITH Luminescent Watercolor</a></h4>

# %%
meta.string
# Out:
# 'Pearlescent White 5ml Tube – DANIEL SMITH Luminescent Watercolor'

# %%
inner = meta.find('a')

# %%
content = inner.string

# %%
content
# Out:
# 'Pearlescent White 5ml Tube – DANIEL SMITH Luminescent Watercolor'

# %%
link = inner.attrs

# %%
link['href']
# Out:
# 'http://danielsmith.com/pearlescent-white-5ml-tube-daniel-smith-luminescent-watercolor/'

# %%
ref = inner[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-86-3609149ed9ba> in <module>
# ----> 1 ref = inner[0]
#
# ~/anaconda3/lib/python3.7/site-packages/bs4/element.py in __getitem__(self, key)
#    1366         """tag[key] returns the value of the 'key' attribute for the Tag,
#    1367         and throws an exception if it's not there."""
# -> 1368         return self.attrs[key]
#    1369
#    1370     def __iter__(self):
#
# KeyError: 0

# %%
ref

# %%
soup.h4.contents[0]
# Out:
# <a href="http://danielsmith.com/pearlescent-white-5ml-tube-daniel-smith-luminescent-watercolor/">Pearlescent White 5ml Tube – DANIEL SMITH Luminescent Watercolor</a>

# %%
print(soup.get_text())
# Out:
#
#
#
#
#
#
#
# Watercolor 5ml Archives - DANIEL SMITHDANIEL SMITH
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Contact Us
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# About Us
#
# Job Opportunities
#
#
# Artists Love DANIEL SMITH
# Watercolor
#
# Watercolor 15ml
# Watercolor 5ml
# Watercolor Sticks
# Watercolor Half Pan Sets
# Watercolor Sets
# Watercolor Dot Cards
# PrimaTek Watercolors
# Luminescent Watercolors
# Watercolor Ground
# Watercolor Masking Fluid
# Walnut Ink
#
#
# Oil Color
#
# Original Oil
# PrimaTek Original Oils
# Original Oil Mediums
# Water Soluble Oil
# Water Soluble Mediums
# Gesso
#
#
# 2020 Trade Shows
# Blogs
#
# Blog Index
#
#
# Product Resources
#
# Brochures and Color Charts
# Video: The Art of Making Paint
# Color Finder
#
#
# Videos
# Retailers
#
# Online Retailers
# Find a Retailer
#
#
# SHOP NOW
#
#
#
#
#
# Watercolor 5ml Home /Watercolor 5ml
#
#
# ...

# %%
meta['href']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-eebd87d1af2a> in <module>
# ----> 1 meta['href']
#
# TypeError: list indices must be integers or slices, not str

# %%
print(meta.attrs)
# Out:
# {'class': ['post_title']}
